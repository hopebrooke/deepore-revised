# %%
# load google drive content
from google.colab import drive
drive.mount('/content/drive')

# view files in DeePore folder
# %cd /content/drive/MyDrive/hb-final-project

import DeePore as dp
import numpy as np
import h5py
import matplotlib.pyplot as plt

# import updatedDP as udp
import deeporerevised as dpr
import os

dataset ='/content/drive/MyDrive/Project/DeePore_Dataset.h5'
dataset_1 = '/content/drive/MyDrive/Project/DeePore_Compact_Data.h5'
dataset_2 = '/content/drive/MyDrive/Project/DeePore_Compact_Data_2.h5'

# dpr.trainmodel doesn't create Log directory initially
# creating Log directory here to prevent errors
log_dir = '/content/drive/MyDrive/hb-final-project/Logs'
os.makedirs(log_dir, exist_ok=True)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/hb-final-project

# %%
List=dpr.prep(dataset_1, 1)
TrainList, EvalList, TestList = dpr.splitdata(List)

model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=1,reload=1,epochs=10,batch_size=100,ModelType=3, n=1)
# Out:
# Checking the data for outliers. Please wait...
# checking sample: 0
# checking sample: 100
# checking sample: 200
# checking sample: 300
# checking sample: 400
# checking sample: 500
# checking sample: 600
# checking sample: 700
# checking sample: 800
# checking sample: 900
# checking sample: 1000
# checking sample: 1100
# checking sample: 1200
# checking sample: 1300
# checking sample: 1400
# checking sample: 1500
# checking sample: 1600
# checking sample: 1700
# checking sample: 1800
# checking sample: 1900
# checking sample: 2000
# checking sample: 2100
# checking sample: 2200
# checking sample: 2300
# checking sample: 2400
# checking sample: 2500
# checking sample: 2600
# checking sample: 2700
# checking sample: 2800
# checking sample: 2900
# checking sample: 3000
# checking sample: 3100
# checking sample: 3200
# checking sample: 3300
# checking sample: 3400
# checking sample: 3500
# checking sample: 3600
# checking sample: 3700
# checking sample: 3800
# checking sample: 3900
# ...

# %%
dpr.testmodel(model,dataset_1,TestList, ModelType=3, n=1)
# Out:
# 50/50 [==============================] - 0s 6ms/step
#
# # Evaluate on 1596 test data
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0046 - mse: 0.0046

# %%
model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=1, reload=1,epochs=20,batch_size=100,ModelType=3, n=1)
# Out:
# Epoch 1/20
# 127/127 [==============================] - 250s 2s/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 2/20
# 127/127 [==============================] - 241s 2s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 3/20
# 127/127 [==============================] - 236s 2s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 4/20
# 127/127 [==============================] - 273s 2s/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 5/20
# 127/127 [==============================] - 231s 2s/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 6/20
# 127/127 [==============================] - 261s 2s/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 7/20
# 127/127 [==============================] - 234s 2s/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 8/20
# ...

# %%
model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=1, reload=1,epochs=20,batch_size=100,ModelType=3, n=1)
# Out:
# Epoch 1/20
# 127/127 [==============================] - 253s 2s/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 2/20
# 127/127 [==============================] - 244s 2s/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 3/20
# 127/127 [==============================] - 279s 2s/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 4/20
# 127/127 [==============================] - 280s 2s/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 5/20
# 127/127 [==============================] - 236s 2s/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 6/20
# 127/127 [==============================] - 242s 2s/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 7/20
# 127/127 [==============================] - 237s 2s/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 8/20
# ...

# %%
model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=1, reload=1,epochs=20,batch_size=100,ModelType=3, n=1)
# Out:
# Epoch 1/20
# 127/127 [==============================] - 236s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 2/20
# 127/127 [==============================] - 231s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 3/20
# 127/127 [==============================] - 239s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 4/20
# 127/127 [==============================] - 272s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 5/20
# 127/127 [==============================] - 260s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 6/20
# 127/127 [==============================] - 233s 2s/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 7/20
# 127/127 [==============================] - 226s 2s/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 8/20
# ...

# %%
model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=1, reload=1,epochs=10,batch_size=100,ModelType=3, n=1)
# Out:
# Epoch 1/10
# 127/127 [==============================] - 251s 2s/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 2/10
# 127/127 [==============================] - 243s 2s/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 3/10
# 127/127 [==============================] - 239s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 4/10
# 127/127 [==============================] - 244s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 5/10
# 127/127 [==============================] - 263s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 6/10
# 127/127 [==============================] - 237s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 7/10
# 127/127 [==============================] - 235s 2s/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 8/10
# ...
