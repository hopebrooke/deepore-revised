# %%
# load google drive content
from google.colab import drive
drive.mount('/content/drive')

# view files in DeePore folder
# %cd /content/drive/MyDrive/hb-final-project

import DeePore as dp
import numpy as np
import h5py
import matplotlib.pyplot as plt
# import updatedDP as udp
import deeporerevised as dpr
import os
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/hb-final-project

# %%
dataset ='/content/drive/MyDrive/Project/DeePore_Dataset.h5'
dataset_1 = '/content/drive/MyDrive/Project/DeePore_Compact_Data.h5'
#dataset_2 = '/content/drive/MyDrive/Project/DeePore_Compact_Data_2.h5'

# dpr.trainmodel doesn't create Log directory initially
# creating Log directory here to prevent errors
log_dir = '/content/drive/MyDrive/hb-final-project/Logs'
os.makedirs(log_dir, exist_ok=True)

# %%
# compact_2 = dpr.create_compact_dataset_2(dataset, '/content/drive/MyDrive/Project/DeePore_Compact_Data_2.h5')

# %%
def visualize(n):       # n - num of slices in each dir
  # read in first entry
  entry = dpr.readh5slice(dataset, 'X', [0])
  # display midslices
  dpr.showentry(entry, n)
  # get properties
  properties = dpr.readh5slice(dataset, 'Y', [0])
  # show and save properties
  dpr.prettyresult(properties, 'sample_gt.txt', units='px')

visualize(1)    # 3 slices - 1 in each dir
visualize(2)    # 6 slices - 2 in each dir
visualize(3)    # 9 slices - 3 in each dir

# %%
#----- RETRAIN - 3-------
# prepare data
List = dpr.prep(dataset_1)
# split data
TrainList, EvalList, TestList = dpr.splitdata(List)
# train
model=dpr.trainmodel(dataset_1,TrainList,EvalList,retrain=0,epochs=50,batch_size=100,ModelType=3)
# test
dpr.testmodel(model,dataset_1,TestList)

# %%
#----- RETRAIN - 6-------
dataset_2 = '/content/drive/MyDrive/Project/DeePore_Compact_Data_2.h5'
# prepare data
List = dpr.prep(dataset_2)
# split data
TrainList, EvalList, TestList = dpr.splitdata(List)
# train
model=dpr.trainmodel(dataset_2,TrainList,EvalList,retrain=1,epochs=20,batch_size=100,ModelType=3)
# test
dpr.testmodel(model,dataset_2,TestList)
# Out:
# Cheching the data for outliers. Please wait...
# checking sample0
# checking sample100
# checking sample200
# checking sample300
# checking sample400
# checking sample500
# checking sample600
# checking sample700
# checking sample800
# checking sample900
# checking sample1000
# checking sample1100
# checking sample1200
# checking sample1300
# checking sample1400
# checking sample1500
# checking sample1600
# checking sample1700
# checking sample1800
# checking sample1900
# checking sample2000
# checking sample2100
# checking sample2200
# checking sample2300
# checking sample2400
# checking sample2500
# checking sample2600
# checking sample2700
# checking sample2800
# checking sample2900
# checking sample3000
# checking sample3100
# checking sample3200
# checking sample3300
# checking sample3400
# checking sample3500
# checking sample3600
# checking sample3700
# checking sample3800
# checking sample3900
# checking sample4000
# checking sample4100
# checking sample4200
# checking sample4300
# checking sample4400
# checking sample4500
# checking sample4600
# checking sample4700
# checking sample4800
# checking sample4900
# checking sample5000
# checking sample5100
# checking sample5200
# checking sample5300
# checking sample5400
# checking sample5500
# checking sample5600
# checking sample5700
# checking sample5800
# checking sample5900
# checking sample6000
# checking sample6100
# checking sample6200
# checking sample6300
# checking sample6400
# checking sample6500
# checking sample6600
# checking sample6700
# checking sample6800
# checking sample6900
# checking sample7000
# checking sample7100
# checking sample7200
# checking sample7300
# checking sample7400
# checking sample7500
# checking sample7600
# checking sample7700
# checking sample7800
# checking sample7900
# checking sample8000
# checking sample8100
# checking sample8200
# checking sample8300
# checking sample8400
# checking sample8500
# checking sample8600
# checking sample8700
# checking sample8800
# checking sample8900
# checking sample9000
# checking sample9100
# checking sample9200
# checking sample9300
# checking sample9400
# checking sample9500
# checking sample9600
# checking sample9700
# checking sample9800
# checking sample9900
# checking sample10000
# checking sample10100
# checking sample10200
# checking sample10300
# checking sample10400
# checking sample10500
# checking sample10600
# checking sample10700
# checking sample10800
# checking sample10900
# checking sample11000
# checking sample11100
# checking sample11200
# checking sample11300
# checking sample11400
# checking sample11500
# checking sample11600
# checking sample11700
# checking sample11800
# checking sample11900
# checking sample12000
# checking sample12100
# checking sample12200
# checking sample12300
# checking sample12400
# checking sample12500
# checking sample12600
# checking sample12700
# checking sample12800
# checking sample12900
# checking sample13000
# checking sample13100
# checking sample13200
# checking sample13300
# checking sample13400
# checking sample13500
# checking sample13600
# checking sample13700
# checking sample13800
# checking sample13900
# checking sample14000
# checking sample14100
# checking sample14200
# checking sample14300
# checking sample14400
# checking sample14500
# checking sample14600
# checking sample14700
# checking sample14800
# checking sample14900
# checking sample15000
# checking sample15100
# checking sample15200
# checking sample15300
# checking sample15400
# checking sample15500
# checking sample15600
# checking sample15700
# checking sample15800
# checking sample15900
# checking sample16000
# checking sample16100
# checking sample16200
# checking sample16300
# checking sample16400
# checking sample16500
# checking sample16600
# checking sample16700
# checking sample16800
# checking sample16900
# checking sample17000
# checking sample17100
# checking sample17200
# checking sample17300
# checking sample17400
# checking sample17500
# checking sample17600
# Epoch 1/20
# 127/127 [==============================] - 450s 4s/step - loss: 0.1576 - mse: 0.1576 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 2/20
# 127/127 [==============================] - 442s 4s/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1581 - val_mse: 0.1581
# Epoch 3/20
# 127/127 [==============================] - 446s 4s/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1578 - val_mse: 0.1578
# Epoch 4/20
# 127/127 [==============================] - 457s 4s/step - loss: 0.1569 - mse: 0.1569 - val_loss: 0.1574 - val_mse: 0.1574
# Epoch 5/20
# 127/127 [==============================] - 428s 3s/step - loss: 0.1564 - mse: 0.1564 - val_loss: 0.1569 - val_mse: 0.1569
# Epoch 6/20
# 127/127 [==============================] - 428s 3s/step - loss: 0.1558 - mse: 0.1558 - val_loss: 0.1561 - val_mse: 0.1561
# Epoch 7/20
# 127/127 [==============================] - 433s 3s/step - loss: 0.1549 - mse: 0.1549 - val_loss: 0.1551 - val_mse: 0.1551
# Epoch 8/20
# 127/127 [==============================] - 435s 3s/step - loss: 0.1536 - mse: 0.1536 - val_loss: 0.1537 - val_mse: 0.1537
# Epoch 9/20
# 127/127 [==============================] - 427s 3s/step - loss: 0.1519 - mse: 0.1519 - val_loss: 0.1516 - val_mse: 0.1516
# Epoch 10/20
# 127/127 [==============================] - 428s 3s/step - loss: 0.1494 - mse: 0.1494 - val_loss: 0.1486 - val_mse: 0.1486
# Epoch 11/20
# 127/127 [==============================] - 439s 3s/step - loss: 0.1458 - mse: 0.1458 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 12/20
# 127/127 [==============================] - 425s 3s/step - loss: 0.1401 - mse: 0.1401 - val_loss: 0.1372 - val_mse: 0.1372
# Epoch 13/20
# 127/127 [==============================] - 428s 3s/step - loss: 0.1315 - mse: 0.1315 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 14/20
# 127/127 [==============================] - 433s 3s/step - loss: 0.1183 - mse: 0.1183 - val_loss: 0.1105 - val_mse: 0.1105
# Epoch 15/20
# 127/127 [==============================] - 431s 3s/step - loss: 0.0994 - mse: 0.0994 - val_loss: 0.0886 - val_mse: 0.0886
# Epoch 16/20
# 127/127 [==============================] - 429s 3s/step - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0631 - val_mse: 0.0631
# Epoch 17/20
# 127/127 [==============================] - 427s 3s/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.0394 - val_mse: 0.0394
# Epoch 18/20
# 127/127 [==============================] - 435s 3s/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0224 - val_mse: 0.0224
# Epoch 19/20
# 127/127 [==============================] - 434s 3s/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 20/20
# 127/127 [==============================] - 433s 3s/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0087 - val_mse: 0.0087
# 50/50 [==============================] - 1s 10ms/step
#
# # Evaluate on 1596 test data
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0090 - mse: 0.0090
