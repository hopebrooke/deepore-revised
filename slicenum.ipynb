# %%
# load google drive content
from google.colab import drive
drive.mount('/content/drive')

# view files in DeePore folder
# %cd /content/drive/MyDrive/hb-final-project

# import DeePore as dp
import numpy as np
import h5py
import matplotlib.pyplot as plt
# import updatedDP as udp
import DeepPoreRevised as dpr
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/hb-final-project
# Data		      .git	  Model8.h5		  Tested_Data_Model5.mat
# DeePorePractice       images	  Model9.h5		  Tested_Data_Model6.mat
# DeePore.py	      Logs	  __pycache__		  Tested_Data_Model7.mat
# DeePoreRevised.ipynb  minmax.npy  README.md		  Tested_Data_Model8.mat
# DeepPoreRevised.py    Model1.h5   results.txt		  Tested_Data_Model9.mat
# Demo1.py	      Model2.h5   sample_gt.txt		  UpdatedDP.ipynb
# Demo2.py	      Model3.h5   slicenum.ipynb	  updatedDP.py
# Demo3.py	      Model4.h5   Tested_Data_Model1.mat  VarNames.txt
# Demo4.py	      Model5.h5   Tested_Data_Model2.mat
# Demo5.py	      Model6.h5   Tested_Data_Model3.mat
# finalproject.ipynb    Model7.h5   Tested_Data_Model4.mat

# %%
def visualize(n):       # n - num of slices in each dir
  # read in first entry
  entry = dpr.readh5slice(dataset, 'X', [0])
  # display midslices
  dpr.showentry(entry, n)
  # get properties
  properties = dpr.readh5slice(dataset, 'Y', [0])
  # show and save properties
  dpr.prettyresult(properties, 'sample_gt.txt', units='px')

# %%
dataset ='/content/drive/MyDrive/Project/DeePore_Dataset.h5'

# dpr.trainmodel doesn't create Log directory initially
# creating Log directory here to prevent errors
log_dir = '/content/drive/MyDrive/hb-final-project/Logs'
os.makedirs(log_dir, exist_ok=True)

# %%
visualize(1)    # 3 slices - 1 in each dir

# %%
visualize(2)    # 6 slices - 2 in each dir

# %%
visualize(3)    # 9 slices - 3 in each dir

# %%
#----- RETRAIN -------
compact_3 = '/content/drive/MyDrive/Project/DeePore_Compact_Data.h5'
# prepare data
List = dpr.prep(compact_3)
# split data
TrainList, EvalList, TestList = dpr.splitdata(List)
# train
model=dpr.trainmodel(compact_3,TrainList,EvalList,retrain=0,epochs=50,batch_size=100,ModelType=3)
# test
dpr.testmodel(model,compact_3,TestList)
# Out:
# Cheching the data for outliers. Please wait...
# checking sample0
# checking sample100
# checking sample200
# checking sample300
# checking sample400
# checking sample500
# checking sample600
# checking sample700
# checking sample800
# checking sample900
# checking sample1000
# checking sample1100
# checking sample1200
# checking sample1300
# checking sample1400
# checking sample1500
# checking sample1600
# checking sample1700
# checking sample1800
# checking sample1900
# checking sample2000
# checking sample2100
# checking sample2200
# checking sample2300
# checking sample2400
# checking sample2500
# checking sample2600
# checking sample2700
# checking sample2800
# checking sample2900
# checking sample3000
# checking sample3100
# checking sample3200
# checking sample3300
# checking sample3400
# checking sample3500
# checking sample3600
# checking sample3700
# checking sample3800
# checking sample3900
# checking sample4000
# checking sample4100
# checking sample4200
# checking sample4300
# checking sample4400
# checking sample4500
# checking sample4600
# checking sample4700
# checking sample4800
# checking sample4900
# checking sample5000
# checking sample5100
# checking sample5200
# checking sample5300
# checking sample5400
# checking sample5500
# checking sample5600
# checking sample5700
# checking sample5800
# checking sample5900
# checking sample6000
# checking sample6100
# checking sample6200
# checking sample6300
# checking sample6400
# checking sample6500
# checking sample6600
# checking sample6700
# checking sample6800
# checking sample6900
# checking sample7000
# checking sample7100
# checking sample7200
# checking sample7300
# checking sample7400
# checking sample7500
# checking sample7600
# checking sample7700
# checking sample7800
# checking sample7900
# checking sample8000
# checking sample8100
# checking sample8200
# checking sample8300
# checking sample8400
# checking sample8500
# checking sample8600
# checking sample8700
# checking sample8800
# checking sample8900
# checking sample9000
# checking sample9100
# checking sample9200
# checking sample9300
# checking sample9400
# checking sample9500
# checking sample9600
# checking sample9700
# checking sample9800
# checking sample9900
# checking sample10000
# checking sample10100
# checking sample10200
# checking sample10300
# checking sample10400
# checking sample10500
# checking sample10600
# checking sample10700
# checking sample10800
# checking sample10900
# checking sample11000
# checking sample11100
# checking sample11200
# checking sample11300
# checking sample11400
# checking sample11500
# checking sample11600
# checking sample11700
# checking sample11800
# checking sample11900
# checking sample12000
# checking sample12100
# checking sample12200
# checking sample12300
# checking sample12400
# checking sample12500
# checking sample12600
# checking sample12700
# checking sample12800
# checking sample12900
# checking sample13000
# checking sample13100
# checking sample13200
# checking sample13300
# checking sample13400
# checking sample13500
# checking sample13600
# checking sample13700
# checking sample13800
# checking sample13900
# checking sample14000
# checking sample14100
# checking sample14200
# checking sample14300
# checking sample14400
# checking sample14500
# checking sample14600
# checking sample14700
# checking sample14800
# checking sample14900
# checking sample15000
# checking sample15100
# checking sample15200
# checking sample15300
# checking sample15400
# checking sample15500
# checking sample15600
# checking sample15700
# checking sample15800
# checking sample15900
# checking sample16000
# checking sample16100
# checking sample16200
# checking sample16300
# checking sample16400
# checking sample16500
# checking sample16600
# checking sample16700
# checking sample16800
# checking sample16900
# checking sample17000
# checking sample17100
# checking sample17200
# checking sample17300
# checking sample17400
# checking sample17500
# checking sample17600
# 50/50 [==============================] - 3s 10ms/step
#
# # Evaluate on 1596 test data
# 32/32 [==============================] - 2s 15ms/step - loss: 0.0072 - mse: 0.0072
